# %%
# %%html
# <style>.container { width:75% !important; }</style>
# <link rel='stylesheet' type='text/css' href='static/css_backup/mobile-package-094623.css'>
# <link rel='stylesheet' type='text/css' href='static/css_backup/homepage-package-3bd234.css'>
#
# <body>
#   <article id="homepage">
#     <a id="library-section"></a>
#     <div class="library-section">
#       <div class="section-separator library-section-separator">
#         <h1>Machine Learning</h1>
#         <!--<center><img src="static/images/logoNipype_tutorial.png" width=700></center>-->
#         <p>Welcome to the Machine Learning Tutorial!
#             It covers various Machine Learning concepts and algorithms. Notebooks will use Python environment together with ML libraries, Scikit-learn, Nilearn.
#             </p><p>
#             All of the notebooks used in this tutorial can be found on <a href="https://github.com/neuro-data-science/neuroML/">github:neuro-data-science/neuroML</a>.
#             </p><p>
#             For the tutorial, we will use a Docker container. You need to install a <a href="http://www.docker.com/">Docker</a> and download a docker image that provides you a
#             environment.
#             </p>
#       </div>
#
#       <!--Comment: to change the color of the title or section, change the second h2 class argument and the third div
#             argument to either science, computing, humanities, test-prep or economics-finance-domain-->
#
#       <!--to change the number of rows per column, change the last number in 'pure-u-1-3'.
#        For example, to have three columns, change the value to 'pure-u-1-3'-->
#
#       <h2 class="domain-header economics-finance-domain"><a class="domain-title">Introductory</a></h2>
#       <p>This section is meant as a general overview for ML techniques.</p>
#       <div class="pure-g domain-table-container economics-finance-domain">
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/introductory_general.ipynb">General ML</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/introductory_predictin_errors.ip\
# ynb">Prediction errors</a>
#        <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/introductory_nilearn.ipynb">Nilearn</a>
#       </div>
#
#       <h2 class="domain-header humanities"><a class="domain-title">Intermediate and advanced notebooks forthcoming</a></h2>
#       <p> If you would like to help, join the discussion <a target="_blank" href="https://docs.google.com/document/d/1LY7U_v01RieRWiNGRa-dpSwLyOKk1Hjed9Do6Ejtrao/edit"> here </a>.
#       <!--
#       <h2 class="domain-header humanities"><a class="domain-title">Intermediate</a></h2>
#       <p>This section will introduce you to extended interactive visualizations.</p>
#       <div class="pure-g domain-table-container humanities">
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/intermediate_combo_panels.ipynb">Combined visualizations</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/intermediate_interactive.ipynb">Interactive and synced displays</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/intermediate_interactive.ipynb">Streaming data visualization</a>
#       </div>
#
#       <h2 class="domain-header science"><a class="domain-title">Advanced</a></h2>
#       <p>In this section you will encounter concepts that scale with data. Some of these techniques may rely on external services
#       and specialized hardware.
#       </p>
#       <div class="pure-g domain-table-container science">
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/advanced_scaling.ipynb">Scaling to many</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/advanced_gog.ipynb">Grammar of graphics</a>
#         <a class="subject-link pure-u-1-4" target="_blank" href="notebooks/advanced_volvis.ipynb">Really large images</a>
#       </div>
#       -->
#
#       <h2 class="domain-header test-prep"><a class="domain-title">External Resources</a></h2>
#       <p>This section will give you helpful links and resources used in the notebooks.</p>
#       <div class="pure-g domain-table-container test-prep">
#         <a target="_blank" href="http://scikit-learn.org/stable/user_guide.html">scikit-learn user guide</a>
#         <a target="_blank" href="http://nilearn.github.io/user_guide.html">Nilearn user guide</a>
#         <a target="_blank" href="https://github.com/jakevdp/sklearn_tutorial">Jake Vanderplas tutorial</a>
#         <a target="_blank" href="https://github.com/mlunacek/meetup_data_science_2016">Monte Lunacek tutorial</a>
#     </div>
#
#     </div>
#   </article>
# </body>
#
# <!--The following code will cause the code cell to disappear-->
#
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
#
# <hr/>
#
# To inspect the html code of this page, click: <form action="javascript:code_toggle()"><input type="submit" value="Show HTML code"></form>
# Out:
# <style>.container { width:75% !important; }</style>
# <link rel='stylesheet' type='text/css' href='static/css_backup/mobile-package-094623.css'>
# <link rel='stylesheet' type='text/css' href='static/css_backup/homepage-package-3bd234.css'>
#
# <body>
#   <article id="homepage">
#     <a id="library-section"></a>
#     <div class="library-section">
#       <div class="section-separator library-section-separator">
#         <h1>Machine Learning</h1>
#         <!--<center><img src="static/images/logoNipype_tutorial.png" width=700></center>-->
#         <p>Welcome to the Machine Learning Tutorial!
#             It covers various Machine Learning concepts and algorithms. Notebooks will use Python environment together with ML libraries, Scikit-learn, Nilearn.
#             </p><p>
#             All of the notebooks used in this tutorial can be found on <a href="https://github.com/neuro-data-science/neuroML/">github:neuro-data-science/neuroML</a>.
#             </p><p>
# ...
